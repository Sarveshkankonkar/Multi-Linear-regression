# %% [markdown]
# Q1: Consider only the below columns and prepare a prediction model for predicting Price.
#
# Corolla<-Corolla c("Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight")

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import influence_plot

# %%
#import warnings to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading a csv file
toyota=pd.read_csv('ToyotaCorolla (2).csv',encoding='iso-8859-1')
toyota.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
toyota.shape
# Out:
# (1436, 38)

# %% [markdown]
# # EDA

# %%
toyota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
toyota=toyota.iloc[:,[2,3,6,8,12,13,15,16,17]]
toyota
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
# Renaming
toyota=toyota.rename({'Age_08_04':'Age','Quarterly_Tax':'QTAX'},axis=1)
toyota.head()
# Out:
#    Price  Age     KM  HP    cc  Doors  Gears  QTAX  Weight
# 0  13500   23  46986  90  2000      3      5   210    1165
# 1  13750   23  72937  90  2000      3      5   210    1165
# 2  13950   24  41711  90  2000      3      5   210    1165
# 3  14950   26  48000  90  2000      3      5   210    1165
# 4  13750   30  38500  90  2000      3      5   210    1170

# %%
toyota.dtypes
# Out:
# Price     int64
# Age       int64
# KM        int64
# HP        int64
# cc        int64
# Doors     int64
# Gears     int64
# QTAX      int64
# Weight    int64
# dtype: object

# %%
# checking fr null value
toyota.isnull().sum()
# Out:
# Price     0
# Age       0
# KM        0
# HP        0
# cc        0
# Doors     0
# Gears     0
# QTAX      0
# Weight    0
# dtype: int64

# %%
toyota.describe()
# Out:
#               Price          Age             KM           HP           cc  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors        Gears         QTAX      Weight
# count  1436.000000  1436.000000  1436.000000  1436.00000
# mean      4.033426     5.026462    87.122563  1072.45961
# std       0.952677     0.188510    41.128611    52.64112
# min       2.000000     3.000000    19.000000  1000.00000
# ...

# %%
 #checking for if there is any duplicate row
toyota[toyota.duplicated()]
# Out:
#      Price  Age     KM   HP    cc  Doors  Gears  QTAX  Weight
# 113  24950    8  13253  116  2000      5      5   234    1320

# %%
# dropping duplicate row
toyota=toyota.drop(113)

# %% [markdown]
# # Corelation Analysis

# %%
toyota.corr()
# Out:
#            Price       Age        KM        HP        cc     Doors     Gears  \
# Price   1.000000 -0.876273 -0.569420  0.314134  0.124375  0.183604  0.063831
# Age    -0.876273  1.000000  0.504575 -0.155293 -0.096549 -0.146929 -0.005629
# KM     -0.569420  0.504575  1.000000 -0.332904  0.103822 -0.035193  0.014890
# HP      0.314134 -0.155293 -0.332904  1.000000  0.035207  0.091803  0.209642
# cc      0.124375 -0.096549  0.103822  0.035207  1.000000  0.079254  0.014732
# Doors   0.183604 -0.146929 -0.035193  0.091803  0.079254  1.000000 -0.160101
# Gears   0.063831 -0.005629  0.014890  0.209642  0.014732 -0.160101  1.000000
# QTAX    0.211508 -0.193319  0.283312 -0.302287  0.305982  0.107353 -0.005125
# Weight  0.575869 -0.466484 -0.023969  0.087143  0.335077  0.301734  0.021238
#
#             QTAX    Weight
# Price   0.211508  0.575869
# Age    -0.193319 -0.466484
# KM      0.283312 -0.023969
# HP     -0.302287  0.087143
# cc      0.305982  0.335077
# Doors   0.107353  0.301734
# ...

# %%
plt.figure(figsize=(20,10))
sns.set_style(style='ticks')
sns.pairplot(toyota)
plt.show()

# %%
#making a heatmap to check correlation
plt.figure(figsize=(20,10))
sns.heatmap(toyota.corr(),annot=True,xticklabels=True,cmap="YlGnBu")
plt.show()

# %% [markdown]
# # Model Building

# %%
model=smf.ols('Price~Age+KM+HP+cc+Doors+Gears+QTAX+Weight',data=toyota).fit()
model

# %%
#Coefficients
model.params
# Out:
# Intercept   -5472.540368
# Age          -121.713891
# KM             -0.020737
# HP             31.584612
# cc             -0.118558
# Doors          -0.920189
# Gears         597.715894
# QTAX            3.858805
# Weight         16.855470
# dtype: float64

# %%
# Finding t-values & p-values
print(model.tvalues, '\n', np.round(model.pvalues,5))
# Out:
# Intercept    -3.875273
# Age         -46.551876
# KM          -16.552424
# HP           11.209719
# cc           -1.316436
# Doors        -0.023012
# Gears         3.034563
# QTAX          2.944198
# Weight       15.760663
# dtype: float64
#  Intercept    0.00011
# Age          0.00000
# KM           0.00000
# HP           0.00000
# cc           0.18824
# Doors        0.98164
# Gears        0.00245
# QTAX         0.00329
# Weight       0.00000
# dtype: float64

# %%
# R-squared values
model.rsquared,model.rsquared_adj
#when adj_rsquared is greater than rsquqred we add irrelevant feature
# Out:
# (0.8625200256947, 0.8617487495415146)

# %% [markdown]
# Variable 'CC' & 'Doors' have insignificant pvalues.
#
# Here the p value for 'cc' and 'Doors' is > 0.05, build simple linear regression and multi linear regression models to see pvalues of 'CC' & 'Doors'.

# %%
# simple linear regression to check pvalue of 'cc'
slr_a=smf.ols('Price~cc',data=toyota).fit()
slr_a.tvalues, np.round(slr_a.pvalues,6)
# Out:
# (Intercept    24.879592
#  cc            4.745039
#  dtype: float64,
#  Intercept    0.000000
#  cc           0.000002
#  dtype: float64)

# %% [markdown]
# cc have signicant p value

# %%
# simple linear regression to check pvalue of 'Doors'
slr_=smf.ols('Price~Doors',data=toyota).fit()
slr_.tvalues, slr_.pvalues
# Out:
# (Intercept    19.421546
#  Doors         7.070520
#  dtype: float64,
#  Intercept    8.976407e-75
#  Doors        2.404166e-12
#  dtype: float64)

# %% [markdown]
# Doors have significant pvalue

# %%
#multi-linear regression to check p valu of both 'ADMS' & 'MKTS'
mlr_am=smf.ols('Price~cc+Doors',data=toyota).fit()
mlr_am.tvalues, mlr_am.pvalues
# Out:
# (Intercept    12.786341
#  cc            4.268006
#  Doors         6.752236
#  dtype: float64,
#  Intercept    1.580945e-35
#  cc           2.101878e-05
#  Doors        2.109558e-11
#  dtype: float64)

# %% [markdown]
# both the varibles have significant pvalues
# That means both the features are important.

# %% [markdown]
# # Model Valiadation Techniques
# 1. Collinearity Check (Calculating VIF)

# %%
# 1) Collinearity Problem Check
# Detecting multicolinearity using vif
# Calculate VIF = 1/(1-Rsquare) for all independent variables
rsq_age=smf.ols('Age~KM+HP+cc+Doors+Gears+QTAX+Weight',data=toyota).fit().rsquared
vif_age=1/(1-rsq_age)

rsq_km=smf.ols('KM~Age+HP+cc+Doors+Gears+QTAX+Weight',data=toyota).fit().rsquared
vif_km=1/(1-rsq_km)

rsq_hp=smf.ols('HP~Age+KM+cc+Doors+Gears+QTAX+Weight',data=toyota).fit().rsquared
vif_hp=1/(1-rsq_hp)

rsq_cc=smf.ols('cc~Age+KM+HP+Doors+Gears+QTAX+Weight',data=toyota).fit().rsquared
vif_cc=1/(1-rsq_cc)

rsq_doors=smf.ols('Doors~Age+KM+HP+cc+Gears+QTAX+Weight',data=toyota).fit().rsquared
vif_doors=1/(1-rsq_doors)

rsq_gears=smf.ols('Gears~Age+KM+HP+cc+Doors+QTAX+Weight',data=toyota).fit().rsquared
vif_gears=1/(1-rsq_gears)

rsq_qt=smf.ols('QTAX~Age+KM+HP+cc+Doors+Gears+Weight',data=toyota).fit().rsquared
vif_qt=1/(1-rsq_qt)

rsq_weight=smf.ols('Weight~Age+KM+HP+cc+Doors+Gears+QTAX',data=toyota).fit().rsquared
vif_weight=1/(1-rsq_weight)


# Storing vif values in a data frame
d1 = {'Attributes':['Age','KM','HP','cc','Doors','Gears','QTAX','Weight'],'VIF':[vif_age,vif_km,vif_hp,vif_cc,vif_doors,vif_gears,vif_qt,vif_weight]}
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
#   Attributes       VIF
# 0        Age  1.876236
# 1         KM  1.757178
# 2         HP  1.419180
# 3         cc  1.163470
# 4      Doors  1.155890
# 5      Gears  1.098843
# 6       QTAX  2.295375
# 7     Weight  2.487180

# %% [markdown]
# No value of VIF is greater than 20 , we can say that there is no collinearity problem. So we will consider all columns(features) for building the model..
#
# As a general rule of thumb, VIF values greater than 5 or 10 are considered to indicate problematic levels of multicollinearity.

# %% [markdown]
# # 2. Residual Analysis
# Test for Normality of Residuals (Q-Q Plot)

# %%
plt.figure(figsize=(19,7))
qqplot=sm.qqplot(model.resid,line='q')
plt.title('Normal Q-Q plot of Residuals')
plt.show()

# %%
sns.distplot(model.resid)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
model.resid
# Out:
# 0      -3291.958871
# 1      -2503.800414
# 2      -2829.635210
# 3      -1455.789389
# 4      -2450.217277
#            ...
# 1431   -1294.255037
# 1432    2552.422658
# 1433      44.565598
# 1434   -1329.222041
# 1435   -3446.087526
# Length: 1435, dtype: float64

# %%
list(np.where(model.resid<-5000))
# Out:
# [array([190, 191, 220, 600, 959], dtype=int64)]

# %% [markdown]
# # Residual Plot for Homoscedasticity or Heteroscedasticity ( Error vs Target)

# %%
# Test for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values)
def standardized_values (vals):
    return (vals-vals.mean())/vals.std()
    
# def standrs_scaling(X):                 
#     return (x - x.mean())/x.std()
# def get_standardized_values( vals ):
#     return (vals - vals.mean())/vals.std()

# %%
plt.scatter(standardized_values(model.fittedvalues),standardized_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('standardized fitted values'),
plt.ylabel('standardized residual values')
plt.show()

# %% [markdown]
# Error VS Target should have no pattern.As there Currently The plot between Error and Target is Homoscedastic.

# %% [markdown]
# # Model Deletion Diagnostics (checking Outliers or Influencers in ROWS)
# Two techniques
# 1. Cook's Distance (Work On Rows)

# %%
# 1. Cook's Distance: If Cook's distance > 1, then it's an outlier
# Get influencers using cook's distance
(c,_)=model.get_influence().cooks_distance #.cooks_distance this atribute detect outlier with respect to the Rows..
c
# Out:
# array([7.22221054e-03, 3.94547973e-03, 5.44224039e-03, ...,
#        8.04110550e-07, 6.99854767e-04, 1.08408002e-02])

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 8))
plt.stem(np.arange(len(toyota)), np.round(c, 5))  # np.round(c, 5) -> it roundup the values in 5 digits
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
#index and value of influencer where c is more than .5
(np.argmax(c),np.max(c))
# Out:
# (80, 78.72950582248232)

# %% [markdown]
# # 2. Leverage value

# %%
# 2. Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers
influence_plot(model)
plt.show()

# %% [markdown]
# From the above plot, we can say that that data point 80 is the influencer

# %%
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints
k=toyota.shape[1]
n=toyota.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.020905923344947737

# %%
toyota[toyota.index.isin([80])]
# Out:
#     Price  Age     KM   HP     cc  Doors  Gears  QTAX  Weight
# 80  18950   25  20019  110  16000      5      5   100    1180

# %%
#Dropthe data points which are influencers and reasign the row number (reset_index())
toyota1=toyota.drop(toyota.index[[80]],axis=0).reset_index(drop=True)
toyota1
# Out:
#       Price  Age     KM   HP    cc  Doors  Gears  QTAX  Weight
# 0     13500   23  46986   90  2000      3      5   210    1165
# 1     13750   23  72937   90  2000      3      5   210    1165
# 2     13950   24  41711   90  2000      3      5   210    1165
# 3     14950   26  48000   90  2000      3      5   210    1165
# 4     13750   30  38500   90  2000      3      5   210    1170
# ...     ...  ...    ...  ...   ...    ...    ...   ...     ...
# 1429   7500   69  20544   86  1300      3      5    69    1025
# 1430  10845   72  19000   86  1300      3      5    69    1015
# 1431   8500   71  17016   86  1300      3      5    69    1015
# 1432   7250   70  16916   86  1300      3      5    69    1015
# 1433   6950   76      1  110  1600      5      5    19    1114
#
# [1434 rows x 9 columns]

# %% [markdown]
# Model Deletion Diagnostics and Final Model

# %%
FinalModel = smf.ols('Price~Age+KM+HP+cc+Doors+Gears+QTAX+Weight',data=toyota1).fit()

# %%
# R-squared values and adj R- squared value
FinalModel.rsquared,FinalModel.rsquared_adj
# Out:
# (0.8681163912634053, 0.867375992056463)

# %% [markdown]
# The model Accuracy is 86.8%.

# %% [markdown]
# Model Prediction

# %%
# New data for prediction is
new_data=pd.DataFrame({'Age':70,"KM":90000,"HP":110,'cc':2000,'Doors':6,'Gears':6,'QTAX':208,'Weight':1168},index=[0])
new_data
# Out:
#    Age     KM   HP    cc  Doors  Gears  QTAX  Weight
# 0   70  90000  110  2000      6      6   208    1168

# %%
# Manual Prediction of Price
FinalModel.predict(new_data)
# Out:
# 0    11358.484308
# dtype: float64

# %%
# Automatic Prediction of Price 
pred_y=FinalModel.predict(toyota1)
pred_y
# Out:
# 0       16513.565909
# 1       16051.656226
# 2       16486.949796
# 3       16133.995128
# 4       15921.372341
#             ...
# 1429     8970.611964
# 1430     8435.944671
# 1431     8591.765915
# 1432     8714.053275
# 1433     9966.948423
# Length: 1434, dtype: float64

# %% [markdown]
# # Table containing R^2 value for each prepared model

# %%
d2={'Prep_Models':['model','FinalModel'],'Rsquared':[model.rsquared,FinalModel.rsquared]}
table=pd.DataFrame(d2)
table
# Out:
#   Prep_Models  Rsquared
# 0       model  0.862520
# 1  FinalModel  0.868116
